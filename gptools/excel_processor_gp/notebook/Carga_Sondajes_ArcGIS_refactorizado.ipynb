# %% [markdown]
# # Actualización de Collar_Recomendado desde Excel + SNDTGIS_ACQ
#
# Este notebook reproduce el flujo revisado con el cliente: lee `CONSOLIDADO_PROGRAMA` y `AVANCE MUESTRERA` del Excel, reemplaza las coordenadas disponibles con `SNDTGIS_ACQ`, completa los falsos Este/Norte, reproyecta con `PSAD_1956_To_WGS_1984_16` y opcionalmente reemplaza la feature class mediante `InsertCursor`.

# %%
from pathlib import Path
from pprint import pprint
from actualizar_collar_desde_excel import actualizar_desde_excel

ROOT = Path(r'D:\AMS_EXP')
EXCEL = ROOT / 'notebook' / 'DB Avance Campaña de Perforación 2025-2030_0708.xlsx'
COORDENADAS_CSV = ROOT / 'notebook' / 'SONDAJE_MLP' / 'SNDTGIS_ACQ_02-06-26.csv'
TARGET = ROOT / 'notebook' / 'dataset' / 'Data.gdb' / 'Collar_Recomendado'
EJECUTAR_CARGA = False
print(f'Excel: {EXCEL}')
print(f'Coordenadas: {COORDENADAS_CSV}')
print(f'Destino: {TARGET}')
print(f'Ejecutar carga: {EJECUTAR_CARGA}')

# %% [markdown]
# ## Procesar y actualizar
# Con `EJECUTAR_CARGA=False` se validan ambas entradas y se genera la capa temporal sin modificar la GDB. Cambie el valor a `True` solamente después de revisar el informe.

# %%
resultado = actualizar_desde_excel(
    excel=str(EXCEL),
    coordenadas_csv=str(COORDENADAS_CSV),
    target=str(TARGET),
    ejecutar=EJECUTAR_CARGA,
)
pprint(resultado)
